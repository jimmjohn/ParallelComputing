# %% [markdown]
# # Lesson 4: JIT-compiled Python

# %% [markdown]
# Although array-oriented programming lets you use precompiled (fast) numerical calculations in a dynamic interpreter like Python (or MATLAB, or APL, ...), it has three shortcomings:

# %% [markdown]
#   1. It may be unfamiliar. If you learn programming with `for` loops and `if` branches, it can be hard to rethink problems in terms of mappers, reducers, slices, `axis`, and such.

# %% [markdown]
#   2. Allocating new arrays in each intermediate step is slower than a single pass and uses more memory (for multiple reasons).

# %% [markdown]
#   3. There are types of problems that don't fit the array-oriented paradigm well, such as algorithms that must "iterate until converged."

# %% [markdown]
# Just-In-Time (JIT) compilation is another way to get fast numerical calculations in a dynamic interpreter.
#
# <br><br><br>

# %% [markdown]
# I advocate for both techniques because
#
#   * array-oriented programming fits the cadence of data analysis;
#   * JIT-compilation provides extra speed, better memory use, or is just an easier way to solve problems when necessary.

# %% [markdown]
# Demonstration of memory use:
#
# <br>

# %%
import awkward as ak

# %% [markdown]
# <br>

# %%
array = ak.Array([range(20), []])

# %% [markdown]
# <br>

# %%
array.nbytes
# Out:
# 184

# %%
ak.combinations(array, 2).nbytes
# Out:
# 3064

# %%
ak.combinations(array, 3).nbytes
# Out:
# 27384

# %%
ak.combinations(array, 4).nbytes
# Out:
# 155064

# %%
ak.combinations(array, 5).nbytes
# Out:
# 620184

# %% [markdown]
# # Just in time compiler
#
# C/C++   -- static compilation
#
# JIT - Java/Javascript
#
# Difference - Look at the program running. And optimize it after it sees it runnig
#
# **Magic**
#
# - Static compiler - Reads the entire program and convert to machine code
# - Interpreter - Execute line by line.
# - JIT compiler - Suppose you are calling a function multiple times, JIT compiler will run in the normal interpreted code initially. But since we are calling multiple times, that function is compiled and stored for later calls. So this will be advantageous is we are calling a function many times.
#
# They can be faster than a static compiler in some cases
#
# - **Why?** - Because they got more information

# %% [markdown]
# <br>
#
# Some physics analyses have to combine a large number of particles to form a candidate.

# %% [markdown]
# Demonstration of the "iterate until converged" problem: suppose we want to draw the Mandelbroit set.
#
# <br>
#
# <center>
# <img src="attachment:e5abdf1e-9d6d-4031-b0c0-9d1547aae258.png" width="25%">
# </center>
#
# <br>
#
# This picture is a 2-dimensional grid of complex numbers $c$ (horizontal axis is the real part, vertical axis is the imaginary part of each point $c$), in which we compute
#
# $$z_{i + 1} = \left|{z_i}\right|^2 + c \mbox{\hspace{0.5 cm}with\hspace{0.5 cm}} z_0 = c$$
#
# repeatedly until $z_i$ seems to diverge ($|z_i| > 2$) or we give up (at $i = 20$). The number of iterations required is the color of the pixel.

# %% [markdown]
# Implementation using Python imperative programming:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <br>

# %%
def run_python(height, width):
    y, x = np.ogrid[-1:1:height*1j, -1.5:0:width*1j]
    c = x + y*1j
    fractal = np.full(c.shape, 20, dtype=np.int32)
    for h in range(height):
        for w in range(width):                  # for each pixel (h, w)...
            z = c[h, w]
            for i in range(20):                 # iterate at most 20 times
                z = z**2 + c[h, w]              # applying z → z² + c
                if z.real**2 + z.imag**2 > 4:   # if it diverges (|z| > 2)
                    fractal[h, w] = i           # color the plane with the iteration number
                    break                       # we're done, no need to keep iterating
    return fractal

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_python(200, 300));

# %% [markdown]
# A NumPy solution to this problem would have to remove the `for` loops over pixels,
#
# ```python
# for h in range(height):
#     for w in range(width):
# ```
#
# with a function that performs the loop in precompiled code.
#
# <br>

# %% [markdown]
# The problem is that each pixel `(w, h)` does a different amount of work:
#
# ```python
#         z = c[h, w]
#         for i in range(20):
#             z = z**2 + c[h, w]
#             if abs(z) > 2:
#                 fractal[h, w] = i
#                 break
# ```
#
# <br>

# %% [markdown]
# The array-oriented solution needs to keep track of which pixels have already diverged and which need more computations.
#
# It needs to act on all pixels equally and then correct the diverged ones.

# %%
def run_numpy(height, width):
    y, x = np.ogrid[-1:0:height*1j, -1.5:0:width*1j]
    c = x + y*1j
    fractal = np.full(c.shape, 20, dtype=np.int32)
    z = c
    for i in range(20):
        z = z**2 + c                                 # applying z → z² + c
        diverged = z.real**2 + z.imag**2 > 4         # |z| > 2 is "divergence"
        diverging_now = diverged & (fractal == 20)   # some are already done
        fractal[diverging_now] = i                   # just set the new ones
        z[diverged] = 2                              # clamp diverged at 2
    return fractal

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_numpy(200, 300));

# %% [markdown]
# The NumPy version is faster because even with this handicap, NumPy array operations are faster than Python `for` loops.
#
# <br>

# %%
# %%timeit -r1   # -r1: only run once (it takes too long)

run_python(1000, 1500)

# %% [markdown]
# <br>

# %%
# %%timeit

run_numpy(1000, 1500)

# %% [markdown]
# Ideally, we'd like to take the part of the algorithm that needs to run fast, compile only that, and run it from Python.
#
# <br><br><br>

# %% [markdown]
# Even better if we don't need to rewrite the code from Python to C/C++/other fast language.
#
# <br><br><br>

# %% [markdown]
# [Numba](https://numba.pydata.org/) does that: it compiles a _subset_ of Python in a way that's easy to streamline into other Python code.

# %% [markdown]
# This is the same code as `run_python` except: (1) it is broken into two functions, (2) the second function is decorated with `@nb.jit` to JIT-compile it.

# %%
import numba as nb

# %% [markdown]
# <br>

# %%
def run_numba(height, width):
    y, x = np.ogrid[-1:0:height*1j, -1.5:0:width*1j]  
    return numba_inner_loop(height, width, x, y)

@nb.jit
def numba_inner_loop(height, width, x, y):            # compiled inner loop as a function
    c = x + y*1j
    fractal = np.full(c.shape, 20, dtype=np.int32)
    for h in range(height):                           # Python for loops over the pixels
        for w in range(width):
            z = c[h, w]
            for i in range(20):                       # the "iterate until converged" loop
                z = z**2 + c[h, w]
                if z.real**2 + z.imag**2 > 4:
                    fractal[h, w] = i
                    break                             # pixel is done: break out of the loop
    return fractal

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_numpy(200, 300));

# %% [markdown]
# The Numba version looks like the Python version, but is even faster than the NumPy version.
#
# <br>

# %%
# %%timeit -r1   # -r1: only run once (it takes too long)

run_python(1000, 1500)

# %% [markdown]
# <br>

# %%
# %%timeit

run_numpy(1000, 1500)

# %% [markdown]
# <br>

# %%
# %%timeit

run_numba(1000, 1500)

# %% [markdown]
# But sometimes we have algorithms that are best described in array-oriented form.
#
# <br><br><br>

# %% [markdown]
# Ideally, we'd like to take _those_ algorithms, mark them for compilation, and let that compiler take advantage of the implicit loops in its optimizations.
#
# <br><br><br>

# %% [markdown]
# [JAX](https://jax.readthedocs.io/) does that: it compiles operations on special JAX arrays (no `for` or `if` allowed).

# %% [markdown]
# Below is an adaptation of `run_numpy` for JAX.

# %%
import jax
jax.config.update("jax_platform_name", "cpu")

# %% [markdown]
# <br>

# %%
def run_jax(height, width):
    y, x = jax.numpy.ogrid[-1:0:height*1j, -1.5:0:width*1j]
    c = x + y*1j
    fractal = jax.numpy.full(c.shape, 20, dtype=np.int32)
    return np.asarray(jax_inner_loop(c, fractal).block_until_ready())

@jax.jit
def jax_inner_loop(c, fractal):
    z = c
    for i in range(20):
        z = z**2 + c
        diverged = jax.numpy.absolute(z) > 2
        diverging_now = diverged & (fractal == 20)
        fractal = jax.numpy.where(diverging_now, i, fractal)    # masked assignment → np.where
    return fractal

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_jax(200, 300));

# %% [markdown]
# JAX runs even faster (by using all the CPU cores without even asking).
#
# <br>

# %%
# %%timeit

run_numpy(1000, 1500)

# %% [markdown]
# <br>

# %%
# %%timeit

run_numba(1000, 1500)

# %% [markdown]
# <br>

# %%
# %%timeit

run_jax(1000, 1500)

# %% [markdown]
# | | imperative | array-oriented |
# |--:|:--:|:--:|
# | **no JIT** | Python | NumPy |
# | **JIT-compiled** | Numba | JAX |
#
# <br><br><br>
#
# Generally,
#
# $$\mbox{Python\hspace{0.5 cm}} \ll \mbox{\hspace{0.5 cm}NumPy\hspace{0.5 cm}} \ll \mbox{\hspace{0.5 cm}any JIT compilation}$$
#
# but Numba vs JAX depends on details.

# %% [markdown]
# Thorough study, using this Mandelbrot example: as a [GitHub Gist](https://gist.github.com/jpivarski/da343abd8024834ee8c5aaba691aafc7), on [Google Colab](https://drive.google.com/file/d/1J0l5e0NZm5kEm5BEUDG4neN5EN0VVCnt/view?usp=sharing).
#
# <center>
# <img src="img/plot-mandelbrot-on-all-accelerators.svg" width="100%">
# </center>

# %% [markdown]
# The long history of Python-compiler interfaces:
#
# <center>
# <img src="img/history-of-bindings-2.svg" width="80%">
# </center>

# %% [markdown]
# ## Moving on to the next sessions

# %% [markdown]
# <br><br>
#
# Next, you'll be learning a lot about C++ programming, GPU programming, machine learning, and JAX.
#
# <br><br>
#
# Everything that follows is either accessed through Python or can be.

# %% [markdown]
# ### C++

# %%
# %%writefile run_pybind11.cpp
# #include <complex>
# #include <pybind11/pybind11.h>
# #include <pybind11/numpy.h>
#
# namespace py = pybind11;
#
# void run(int height, int width, py::array_t<std::complex<double>> np_c,
#          py::array_t<int> np_fractal) {
#     std::complex<double>* c = static_cast<std::complex<double>*>(np_c.request().ptr);
#     int* fractal = static_cast<int*>(np_fractal.request().ptr);
#     for (int h = 0;  h < height;  h++) {
#         for (int w = 0;  w < width;  w++) {
#             std::complex<double> ci = c[h + height*w];
#             std::complex<double> z = ci;
#             for (int i = 0;  i < 20;  i++) {
#                 z = z * z + ci;
#                 if (z.real()*z.real() + z.imag()*z.imag() > 4) {
#                     fractal[h + height*w] = i;
#                     break;
# }}}}}
#
# PYBIND11_MODULE(run_pybind11, m) {
#     m.def("run", &run);
# }

# %%
# %%bash
#
# export PYTHON_CONFIG=`which python-config python3-config | head -n1`
#
# c++ -Wall -shared -std=c++11 -fPIC -O3 `python -m pybind11 --includes` run_pybind11.cpp \
#     -o run_pybind11`$PYTHON_CONFIG --extension-suffix`

# %% [markdown]
# <br>

# %%
import run_pybind11

def run_c_plus_plus(height, width):
    y, x = np.ogrid[-1:0:height*1j, -1.5:0:width*1j]
    c = x + y*1j
    fractal = np.full(c.shape, 20, dtype=np.int32)
    run_pybind11.run(height, width, c, fractal)
    return fractal

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_c_plus_plus(2000, 3000));

# %% [markdown]
# ### GPUs

# %%
import cupy as cp

cupy_custom_kernel = cp.RawKernel("""
#include <cupy/complex.cuh>

extern "C" __global__
void cupy_custom_kernel(int height, int width, int* fractal) {
    int x = blockIdx.x * blockDim.x + threadIdx.x;
    int y = blockIdx.y * blockDim.y + threadIdx.y;

    complex<float> j(0.0, 1.0);
    complex<float> z, c;
    z = c = complex<float>(-1.5 + y*1.0/(height + 1)) - j
          + complex<float>(x*1.5)*j/complex<float>(width + 1);

    fractal[y + x*width] = 20;
    for (int i = 0;  i < 20;  i++) {
        z = z * z + c;
        if (z.real()*z.real() + z.imag()*z.imag() > 4) {
            fractal[y + x*width] = i;
            break;
        }
    }
}
""", "cupy_custom_kernel")

# %%
def run_cupy(height, width):
    fractal = cp.empty((height, width), dtype=np.int32)
    griddim = (int(np.ceil(height / 32)), int(np.ceil(width / 32)))
    blockdim = (32, 32)
    cupy_custom_kernel(griddim, blockdim, (height, width, fractal))
    return fractal.get()

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_cupy(2000, 3000));

# %% [markdown]
# <br>
#
# (Machine learning and JAX are usually done in Python.)

# %% [markdown]
# As you go and learn all of these techniques, remember that you can glue it all together with a Python script, and speak a common language of arrays to move your data around.
#
# <br><br><br>

# %% [markdown]
# # Numba Cuda
#
# Till now we have seen CPU JIT with numba

# %%
import numpy as np
import numba as nb
from numba import cuda

@cuda.jit
def cuda_loop(height, width, x, y, fractal):
    h, w = cuda.grid(2)
    if h < height and w < width:
        c = x[h, w] + y[h, w] * 1j
        z = c
        for i in range(20):
            z = z**2 + c
            if z.real**2 + z.imag**2 > 4:
                fractal[h, w] = i
                break

def run_cuda(height, width):
    y, x = np.ogrid[-1:0:height * 1j, -1.5:0:width * 1j]
    fractal = np.full((height, width), 20, dtype=np.int32)
    blocks = (height // 32, width // 32)
    threads = (32, 32)
    cuda_loop[blocks, threads](height, width, x, y, fractal)
    return fractal

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.imshow(run_cuda(200, 300));
# Out:
# /home/jim/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 54 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# ---------------------------------------------------------------------------
# CudaAPIError                              Traceback (most recent call last)
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/cudadrv/driver.py:2830, in CtypesLinker.add_ptx(self, ptx, name)
#    2829 try:
# -> 2830     driver.cuLinkAddData(self.handle, enums.CU_JIT_INPUT_PTX,
#    2831                          ptxbuf, len(ptx), namebuf, 0, None, None)
#    2832 except CudaAPIError as e:
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/cudadrv/driver.py:327, in Driver._ctypes_wrap_fn.<locals>.safe_cuda_api_call(*args)
#     326 retcode = libfn(*args)
# --> 327 self._check_ctypes_error(fname, retcode)
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/cudadrv/driver.py:395, in Driver._check_ctypes_error(self, fname, retcode)
#     394     self._detect_fork()
# --> 395 raise CudaAPIError(retcode, msg)
#
# CudaAPIError: [222] Call to cuLinkAddData results in CUDA_ERROR_UNSUPPORTED_PTX_VERSION
#
# During handling of the above exception, another exception occurred:
#
# LinkerError                               Traceback (most recent call last)
# Cell In[21], line 2
#       1 fig, ax = plt.subplots(1, 1, figsize=(5, 4))
# ----> 2 ax.imshow(run_cuda(200, 300));
#
# Cell In[20], line 22, in run_cuda(height, width)
#      20 blocks = (height // 32, width // 32)
#      21 threads = (32, 32)
# ---> 22 cuda_loop[blocks, threads](height, width, x, y, fractal)
#      23 return fractal
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:539, in _LaunchConfiguration.__call__(self, *args)
#     538 def __call__(self, *args):
# --> 539     return self.dispatcher.call(args, self.griddim, self.blockdim,
#     540                                 self.stream, self.sharedmem)
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:681, in CUDADispatcher.call(self, args, griddim, blockdim, stream, sharedmem)
#     679     kernel = next(iter(self.overloads.values()))
#     680 else:
# --> 681     kernel = _dispatcher.Dispatcher._cuda_call(self, *args)
#     683 kernel.launch(args, griddim, blockdim, stream, sharedmem)
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:689, in CUDADispatcher._compile_for_args(self, *args, **kws)
#     687 assert not kws
#     688 argtypes = [self.typeof_pyval(a) for a in args]
# --> 689 return self.compile(tuple(argtypes))
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:934, in CUDADispatcher.compile(self, sig)
#     932     kernel = _Kernel(self.py_func, argtypes, **self.targetoptions)
#     933     # We call bind to force codegen, so that there is a cubin to cache
# --> 934     kernel.bind()
#     935     self._cache.save_overload(sig, kernel)
#     937 self.add_overload(kernel, argtypes)
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/dispatcher.py:197, in _Kernel.bind(self)
#     193 def bind(self):
#     194     """
#     195     Force binding to current CUDA context
#     196     """
# --> 197     self._codelibrary.get_cufunc()
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/codegen.py:214, in CUDACodeLibrary.get_cufunc(self)
#     211 if cufunc:
#     212     return cufunc
# --> 214 cubin = self.get_cubin(cc=device.compute_capability)
#     215 module = ctx.create_module_image(cubin)
#     217 # Load
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/codegen.py:188, in CUDACodeLibrary.get_cubin(self, cc)
#     186 else:
#     187     ptx = self.get_asm_str(cc=cc)
# --> 188     linker.add_ptx(ptx.encode())
#     190 for path in self._linking_files:
#     191     linker.add_file_guess_ext(path)
#
# File ~/products/conda/miniconda3/envs/tf/lib/python3.9/site-packages/numba/cuda/cudadrv/driver.py:2833, in CtypesLinker.add_ptx(self, ptx, name)
#    2830     driver.cuLinkAddData(self.handle, enums.CU_JIT_INPUT_PTX,
#    2831                          ptxbuf, len(ptx), namebuf, 0, None, None)
#    2832 except CudaAPIError as e:
# -> 2833     raise LinkerError("%s\n%s" % (e, self.error_log))
#
# LinkerError: [222] Call to cuLinkAddData results in CUDA_ERROR_UNSUPPORTED_PTX_VERSION
# ptxas application ptx input, line 9; fatal   : Unsupported .version 7.8; current version is '7.2'
